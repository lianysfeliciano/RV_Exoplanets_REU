# %%
import pandas as pd #Creating a frame to work with the data
import numpy as np #Calculations 
import matplotlib.pyplot as plt #To make the graph
from astropy.io import fits #Used to read the fits file 

Obv1fits=fits.open ("26965_200205.1080.fits")
Obv2fits= fits.open ("26965_201127.1110.fits")
Obv1fits.info ()
Obv2fits.info()
# Out:
# Filename: 26965_200205.1080.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      58   (7920, 86)   float64
#   1  optimal       1 BinTableHDU     97   86R x 17C   [7920D, 7920D, 7920D, 7920D, 7920D, 7920I, 7920D, 7920L, 7920D, 7920D, 7920D, I, 7920D, 7920D, 7920D, 7920D, 7920L]
#   2  EXPOSUREMETER    1 BinTableHDU     62   345R x 3C   [512D, D, 512D]
# Filename: 26965_201127.1110.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      59   (7920, 86)   float64
#   1  optimal       1 BinTableHDU     97   86R x 17C   [7920D, 7920D, 7920D, 7920D, 7920D, 7920I, 7920D, 7920L, 7920D, 7920D, 7920D, I, 7920D, 7920D, 7920D, 7920D, 7920L]
#   2  EXPOSURE METER + BARY_CORR    1 BinTableHDU     64   185R x 3C   [512D, D, 512D]

# %%
from astropy.table import Table 
Obv1Table=Table.read("26965_200205.1080.fits")
Obv2Table=Table.read ("26965_201127.1110.fits")
Obv1Table.info()
Obv2Table.info()
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]
# <Table length=86>
#        name         dtype   shape     unit      class     n_bad
# ------------------ ------- ------- --------- ------------ ------
#         wavelength float64 (7920,) angstroms       Column      0
#           spectrum float64 (7920,)  unitless MaskedColumn  95026
#        uncertainty float64 (7920,)  unitless MaskedColumn  95026
#             offset float64 (7920,)  unitless MaskedColumn  95026
# offset_uncertainty float64 (7920,)  unitless MaskedColumn  95026
#           n_pixels   int16 (7920,)    pixels       Column      0
#        reduced_chi float64 (7920,)  unitless MaskedColumn  95026
#         pixel_mask    bool (7920,)  unitless       Column      0
#          continuum float64 (7920,)           MaskedColumn  95026
#     continuum_mask float64 (7920,)                 Column      0
# ...

# %%
data1 = Obv1fits[0].data.copy() #data1= first observation
print(data1)

#My Chemical Rokmance?? 
#nan= non integer--- could it be easier if we converted the floats to int?
# Out:
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
data1 = Obv1fits[0].data.copy()
plt.plot(data1)
plt.xlabel= ("wavelength")
plt.show ()

data2= Obv2fits[0].data.copy()
plt.plot(data2)
plt.xlabel= ("wavelength")
plt.show()

#here we're plotting the wavelenght but against what?

# %%
plt.plot(data1,data2)
plt.show()
plt.scatter(data1,data2)
plt.plot(data1,data2,color="purple",label='wavelenght')
plt.show()

# %% [markdown]
# # 1080

# %%
a=Obv1Table["spectrum"][85]
b=Obv1Table["continuum"][85]

plt.plot(b,a)
plt.plot(b,b)

plt.show()

# %%
Flux=Obv1Table["spectrum"][85]/Obv1Table["continuum"][85]
Wavelenght=Obv1Table["wavelength"][85]
Continumm= (Obv1Table["continuum"][85]/Obv1Table["continuum"][85])

x=Wavelenght 
y=Flux
z=Continumm

plt.plot(x,y)
plt.plot(x,z)

plt.xlabel ("wavelength")
plt.ylabel ("flux")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 Flux=Obv1Table["spectrum"][85]/Obv1Table["continuum"][85]
#       2 Wavelenght=Obv1Table["wavelength"][85]
#       3 Continumm= (Obv1Table["continuum"][85]/Obv1Table["continuum"][85])
#
# NameError: name 'Obv1Table' is not defined

# %%
Fluxblaze1=Obv1Table["spectrum"][85]*Obv1Table["blaze"][85]
Wavelenght=Obv1Table["wavelength"][85]
Blazecontinumm=(Obv1Table["blaze"][85]/Obv1Table["continuum"][85])
Barrywave=(Obv1Table["spectrum"][85]/Obv1Table["wavelength"][85])


q=Wavelenght 
r=Fluxblaze1
s=Blazecontinumm


plt.plot(q,r)
plt.plot(q,s )
plt.xlabel= ("wavelength")
plt.ylabel= ("flux")

# %% [markdown]
# # 1110

# %%
c=Obv2Table["spectrum"][85]
d=Obv2Table["continuum"][85]

plt.plot(d,c)
plt.plot(d,d)

plt.xlabel=("continuum")
plt.ylabel=("spectrum")
plt.show()

# %%
flux2=Obv2Table["spectrum"][85]/Obv2Table["continuum"][85]
wavelenght2=Obv2Table["wavelength"][85]
continumm= (Obv2Table["continuum"][85]/Obv2Table["continuum"][85])

j=wavelenght2 
k=flux2
l=continumm

plt.plot(j,k)
plt.plot(j,l)
plt.xlabel= ("wavelength")
plt.ylabel= ("flux")
plt.show()

# %%
Fluxblaze2=Obv2Table["spectrum"][85]*Obv1Table["blaze"][85]
Wavelenght2=Obv2Table["wavelength"][85]
Blazecontinumm=(Obv2Table["blaze"][85]/Obv2Table["continuum"][85])

o=Wavelenght2 
p=Fluxblaze2
q=Blazecontinumm

plt.plot(o,p)
plt.plot(o,q)
plt.xlabel= ("wavelength")
plt.ylabel= ("flux")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 import jupyterthemese as jt
#
# ModuleNotFoundError: No module named 'jupyterthemese'

# %%
# hdus: 
#hdus[1] Gives the order or n

# %%
from astropy.io imports
